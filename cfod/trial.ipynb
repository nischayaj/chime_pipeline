# %%
from cfod import catalog

# This gives you the full catalog as a dictionary or structured object
# This is an alternative to the pandas/csv method shown in the tutorial
data = catalog.as_dict()

# If you need to find an FRB's location to open its specific .h5 file:
# You can search the catalog for a name and then use that to load the file
print(data['tns_name'])
